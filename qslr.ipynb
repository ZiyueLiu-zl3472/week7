# %% [markdown]
# <a href="https://colab.research.google.com/github/ZiyueLiu-zl3472/week7/blob/main/qslr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

def MyLM(formula, df):
    fit = smf.ols(formula, data=df).fit()
    # populate the smf.ols function using the formula and fit it
    return fit

# Tools
x = np.arange(1, 4)
y = x * np.random.normal(2, 0.1, 3)
f = "y ~ x"
df = pd.DataFrame({'x': x, 'y': y})
model = smf.ols(f, data=df).fit()
#apply the fit method to the object-object is data
print(model.summary())

# Unit Tests
from sklearn.datasets import load_iris
data = load_iris()
iris = pd.DataFrame(data=data.data, columns=data.feature_names)
# Rename columns to remove spaces and parentheses
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf


# Tools
x = np.arange(1, 4)
y = x * np.random.normal(2, 0.1, 3)
f = "y ~ x"
df = pd.DataFrame({'x': x, 'y': y})
model = smf.ols(f, data=df).fit()
print(model.summary())

# Unit Tests
from sklearn.datasets import load_iris
data = load_iris()
iris = pd.DataFrame(data=data.data, columns=data.feature_names)
# Rename columns to remove spaces and parentheses
iris.columns = iris.columns.str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
# Define the formula with the modified column names
myFormula = "sepal_length_cm ~ petal_length_cm"
fit_iris = smf.ols(formula=myFormula, data=iris).fit()

x = MyLM(myFormula, iris)
np.round(x.params[0], 4) == 4.3066
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                     1982.
# Date:                Wed, 05 Mar 2025   Prob (F-statistic):             0.0143
# Time:                        02:40:41   Log-Likelihood:                 5.3979
# No. Observations:                   3   AIC:                            -6.796
# Df Residuals:                       1   BIC:                            -8.599
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.2680      0.106     -2.531      0.240      -1.614       1.078
# x              2.1826      0.049     44.524      0.014       1.560       2.805
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.000
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.531
# Skew:                          -0.707   Prob(JB):                        0.767
# Kurtosis:                       1.500   Cond. No.                         6.79
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                     437.2
# Date:                Wed, 05 Mar 2025   Prob (F-statistic):             0.0304
# Time:                        02:40:41   Log-Likelihood:                 3.4879
# No. Observations:                   3   AIC:                            -2.976
# Df Residuals:                       1   BIC:                            -4.779
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1855      0.200      0.927      0.524      -2.358       2.729
# x              1.9374      0.093     20.909      0.030       0.760       3.115
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.000
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.531
# Skew:                           0.707   Prob(JB):                        0.767
# Kurtosis:                       1.500   Cond. No.                         6.79
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 3 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 3 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# <ipython-input-24-dc4ac3ced9f6>:50: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   np.round(x.params[0], 4) == 4.3066
# True

# %%
# !pip install rdatasets
from rdatasets import data

import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pandas as pd

# Load the 'cars' dataset
df_cars = data('cars')
plt.scatter(df_cars['speed'], df_cars['dist'])

myFormula='speed~dist'
carFit = smf.ols(formula=myFormula, data=df_cars).fit()

def PlotSLRCI(fit, data):

  # Plot the data
  # Plot the lower confidence interval -
  carFit.conf_int()
  # Plot the upper confidence interval
carFit.conf_int()[1]
# Out:
# Requirement already satisfied: rdatasets in /usr/local/lib/python3.11/dist-packages (0.2.10)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from rdatasets) (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->rdatasets) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->rdatasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->rdatasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->rdatasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->rdatasets) (1.17.0)
# Intercept    10.041973
# dist          0.200743
# Name: 1, dtype: float64

# %%
carFit.conf_int()
# Out:
#                   0          1
# Intercept  6.525838  10.041973
# dist       0.130393   0.200743

# %%
df_cars.head()
# Out:
#    rownames  speed  dist
# 0         1      4     2
# 1         2      4    10
# 2         3      7     4
# 3         4      7    22
# 4         5      8    16
